# %%
# !pip install ultralytics
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Get data set

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ALN1PF4fprbDXxaZWqPz")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(14)
dataset = version.download("yolov5")
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#   Using cached roboflow-1.1.64-py3-none-any.whl.metadata (9.7 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pillow_heif-0.22.0-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# ...
#   Using cached python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# ...
# Using cached roboflow-1.1.64-py3-none-any.whl (85 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
# ...

# %%
dataset.location
# Out:
# 'd:\\Projects\\Football_Analysis\\training\\football-players-detection-14'

# %%
import shutil

shutil.move('football-players-detection-14/train',
            'football-players-detection-14/football-players-detection-1/train'
            )  

shutil.move('football-players-detection-14/test',
            'football-players-detection-14/football-players-detection-1/test'
            )  

shutil.move('football-players-detection-14/valid',
            'football-players-detection-14/football-players-detection-1/valid'
            )
# Out:
# 'football-players-detection-14/football-players-detection-1/valid'

# %% [markdown]
# Trainig

# %%
# !yolo task=detect mode=train model=yolo5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
